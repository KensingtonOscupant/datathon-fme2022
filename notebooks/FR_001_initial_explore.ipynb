# %%
# setup from LF 001

import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

#sns.set_theme(context='paper', font_scale=1.15)

data_dir = '../data/datathon_SC_ACN_22/'

# %%
pd.read_csv(data_dir + 'product_attributes.csv', delimiter=',').head()
# Out:
#   product_id,weight,material_handling
# 0                      1672707,2876,3
# 1                      1694456,2785,5
# 2                      1682865,2751,3
# 3                      1689146,2736,0
# 4                      1664069,2707,4

# %%
pd.read_csv(data_dir + 'orders.csv', delimiter=';')['units'].head(100).plot()
# Out:
# <AxesSubplot:>
