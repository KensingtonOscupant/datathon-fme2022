# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(context='paper', font_scale=1.15)

data_dir = '../data/datathon_SC_ACN_22/'

# %% [markdown]
# ### Data overview

# %%
orders = pd.read_csv(data_dir + 'orders.csv', delimiter=';')
# Out:
# <AxesSubplot:>
